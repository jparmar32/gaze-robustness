# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img_id = "minion"

# %%
img = Image.open(f"./feedback/images/{img_id}.jpg")
plt.imshow(img)

# %%
mask = np.load(f"./feedback/annotations/{img_id}_lungmask.npy")
print(mask.shape)
plt.imshow(mask, cmap="gray", vmin=0, vmax=1)
# Out:
# (224, 224)
