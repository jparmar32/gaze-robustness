# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img_id = "1.2.276.0.7230010.3.1.2.8323329.2214.1517875171.662902_1.2.276.0.7230010.3.1.3.8323329.2214.1517875171.662901_1.2.276.0.7230010.3.1.4.8323329.2214.1517875171.662903"

# %%
img = Image.open(f"./lung_segmentations/images/{img_id}.jpg")
plt.imshow(img)

# %%
mask = np.load(f"./lung_segmentations/annotations/{img_id}_lungmask.npy")
print(mask.shape)
plt.imshow(mask, cmap="gray", vmin=0, vmax=1)
# Out:
# (224, 224)
